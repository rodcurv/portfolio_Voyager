# %% [markdown]
# # Project - Ultimate UFC Dataset

# %% [markdown]
# ## Mounting drive and importing libraries

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Data importing and initial inspection

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Voyager/ufc-master.csv')
df.head()
# Out:
#          R_fighter              B_fighter  ...  r_ko_odds  b_ko_odds
# 0  Jared Cannonier        Kelvin Gastelum  ...      175.0      600.0
# 1       Clay Guida            Mark Madsen  ...      700.0      700.0
# 2    Parker Porter          Chase Sherman  ...      500.0      120.0
# 3     Trevin Jones  Saidyokub Kakhramonov  ...      150.0      600.0
# 4      Vinc Pichel         Austin Hubbard  ...      700.0      550.0
#
# [5 rows x 119 columns]

# %%
df.tail()
# Out:
#            R_fighter       B_fighter  R_odds  ...  b_sub_odds  r_ko_odds  b_ko_odds
# 4833    Duane Ludwig   Darren Elkins    -155  ...         NaN        NaN        NaN
# 4834     John Howard  Daniel Roberts    -210  ...         NaN        NaN        NaN
# 4835  Brendan Schaub   Chase Gormley    -260  ...         NaN        NaN        NaN
# 4836     Mike Pierce   Julio Paulino    -420  ...         NaN        NaN        NaN
# 4837    Eric Schafer     Jason Brilz     140  ...         NaN        NaN        NaN
#
# [5 rows x 119 columns]

# %% [markdown]
# ## Features
#
# * R_fighter - red gloves fighter
# * B_fighter - blue gloves fighter
# * R_odds - red gloves fighter victory odds
# * R_odds - blue gloves fighter victory odds
# * R_ev - profit on a 100 unit winning bet on red gloves fighter
# * B_ev - profit on a 100 unit winning bet on blue gloves fighter
# * date - fight date
# * location - fight location
# * country - fight location (country)
# * Winner - fight winner
# * title_bout - championship fight (True or False)
# * weight_class - division
# * gender - gender (male or female)
# * no_of_rounds - total number of rounds (3 or 5)
# * B_current_lose_streak - blue gloves fighter losing streak
# * B_current_win_streak - blue gloves fighter winning streak
# * B_draw - blue gloves fighter number of draws
# * B_avg_SIG_STR_landed - blue gloves fighter average number of significant strikes landed per minute
# * B_avg_SIG_STR_pct - blue gloves fighter significant striking accuracy
# * B_avg_SUB_ATT - blue gloves fighter average number of submission attempts per 15 minutes
# * B_avg_TD_landed - blue gloves fighter average number of takedowns landed per 15 minutes
# * B_avg_TD_pct - blue gloves fighter takedown accuracy
# * B_longest_win_streak - blue gloves fighter longest win streak
# * B_losses - blue gloves fighter number of losses
# * B_total_rounds_fought - blue gloves fighter total number of rounds fought
# * B_total_title_bouts - blue gloves fighter total number of championship fights
# * B_win_by_Decision_Majority - blue gloves fighter number of wins by majority decision
# * B_win_by_Decision_Split - blue gloves fighter number of wins by split decision
# * B_win_by_Decision_Unanimous - blue gloves fighter number of wins by unanimous decision
# * B_win_by_KO/TKO - blue gloves fighter number of wins by KO/TKO
# * B_win_by_Submission - blue gloves fighter number of wins by submission
# * B_win_by_TKO_Doctor_Stoppage - blue gloves fighter number of wins by TKO (doctor stoppage)
# * B_win - blue gloves fighter number of wins
# * B_Stance - blue gloves fighter main striking stance
# * B_Height_cms - blue gloves fighter height in cm
# * B_Reach_cms - blue gloves fighter reach in cm
# * B_Weight_lbs - blue gloves fighter weight in lb
# * R_current_lose_streak - red gloves fighter losing streak
# * R_current_win_streak - red gloves fighter winning streak
# * **R_draw** - red gloves fighter number of draws (?)
# * R_avg_SIG_STR_landed - red gloves fighter average number of significant strikes landed per minute
# * R_avg_SIG_STR_pct - red gloves fighter significant striking accuracy
# * R_avg_SUB_ATT - red gloves fighter average number of submission attempts per 15 minutes
# * R_avg_TD_landed - red gloves fighter average number of takedowns landed per 15 minutes
# * R_avg_TD_pct - red gloves fighter takedown accuracy
# * R_longest_win_streak - red gloves fighter longest win streak
# * R_losses - red gloves fighter number of losses
# * R_total_rounds_fought - red gloves fighter total number of rounds fought
# * R_total_title_bouts - red gloves fighter total number of championship fights
# * R_win_by_Decision_Majority - red gloves fighter number of wins by majority decision
# * R_win_by_Decision_Split - red gloves fighter number of wins by split decision
# * R_win_by_Decision_Unanimous - red gloves fighter number of wins by unanimous decision
# * R_win_by_KO/TKO - red gloves fighter number of wins by KO/TKO
# * R_win_by_Submission - red gloves fighter number of wins by submission
# * R_win_by_TKO_Doctor_Stoppage - red gloves fighter number of wins by TKO (doctor stoppage)
# * R_win - red gloves fighter number of wins
# * R_Stance - red gloves fighter main striking stance
# * R_Height_cms - red gloves fighter height in cm
# * R_Reach_cms - red gloves fighter reach in cm
# * R_Weight_lbs - red gloves fighter weight in lb
# * R_age - red gloves fighter age
# * B_age - blue gloves fighter age
# * lose_streak_dif - losing streak difference (blue - red)
# * win_streak_dif - winning streak difference (blue - red)
# * longest_win_streak_dif - longest winning streak difference (blue - red)
# * win_dif - number of wins difference (blue - red)
# * loss_dif - number of losses difference (blue - red)
# * total_round_dif - total number of rounds difference (blue - red)
# * total_title_bout_dif - number of championship fights difference (blue - red)
# * ko_dif - number of KOs difference (blue - red)
# * sub_dif - number of submissions difference (blue - red)
# * height_dif - height difference (blue - red) in cm
# * reach_dif - reach difference (blue - red) in cm
# * age_dif - age difference (blue - red)
# * sig_str_dif - average significant strikes per minute difference (blue - red)
# * avg_sub_att_dif - average submission attempts per 15 minutes difference (blue - red)
# * avg_td_dif - average takedown attempts per 15 minutes difference (blue - red)
# * empty_arena - did this fight occur in an empty arena - COVID (0 or 1)
# * **constant_1 - ?????**
# * B_match_weightclass_rank - blue gloves fighter's rank in the division
# * R_match_weightclass_rank - red gloves fighter's rank in the division
# * R_Women's Flyweight_rank - red gloves fighter women's flyweight rank
# * R_Women's Featherweight_rank - red gloves fighter women's featherweight rank
# * R_Women's Strawweight_rank - red gloves fighter women's strawweight rank
# * R_Women's Batamweight_rank - red gloves fighter women's bantamweight rank
# * R_Heavyweight_rank - red gloves fighter heavyweight rank
# * R_Light Heavyweight_rank - red gloves fighter light heavyweight rank
# * R_Middleweight_rank - red gloves fighter middleweight rank
# * R_Welterweight_rank - red gloves fighter welterweight rank
# * R_Lightweight_rank - red gloves fighter lightweight rank
# * R_Featherweight_rank - red gloves fighter featherweight rank
# * R_Bantamweight_rank - red gloves fighter bantamweight rank
# * R_Flyweight_rank - red gloves fighter flyweight rank
# * R_Pound-for-pound_rank - red gloves fighter pound-for-pound rank
# * R_Women's Flyweight_rank - blue gloves fighter women's flyweight rank
# * B_Women's Featherweight_rank - blue gloves fighter women's featherweight rank
# * B_Women's Strawweight_rank - blue gloves fighter women's strawweight rank
# * B_Women's Batamweight_rank - blue gloves fighter women's bantamweight rank
# * B_Heavyweight_rank - blue gloves fighter heavyweight rank
# * B_Light Heavyweight_rank - blue gloves fighter light heavyweight rank
# * B_Middleweight_rank - blue gloves fighter middleweight rank
# * B_Welterweight_rank - blue gloves fighter welterweight rank
# * B_Lightweight_rank - blue gloves fighter lightweight rank
# * B_Featherweight_rank - blue gloves fighter featherweight rank
# * B_Bantamweight_rank - blue gloves fighter bantamweight rank
# * B_Flyweight_rank - blue gloves fighter flyweight rank
# * B_Pound-for-pound_rank - blue gloves fighter pound-for-pound rank
# * better_rank - best ranked fighter (Red, Blue or neither)
# * finish - how the fight finished
# * finish_details - detailed description of finish if available
# * finish_round - round of finish
# * finish_round_time - time of finish
# * total_fight_time_secs - total time of fight in seconds
# * r_dec_odds - red gloves fighter win by decision odds
# * b_dec_odds - blue gloves fighter win by decision odds
# * r_sub_odds - red gloves fighter win by submission odds
# * b_sub_odds - blue gloves fighter win by submission odds
# * r_ko_odds - red gloves fighter win by KO/TKO odds
# * b_ko_odds - blue gloves fighter win by KO/TKO odds

# %%
df.describe()
# Out:
#             R_odds       B_odds  ...    r_ko_odds    b_ko_odds
# count  4838.000000  4838.000000  ...  3790.000000  3777.000000
# mean   -117.110376    65.762919  ...   515.759894   646.823934
# std     268.311775   247.672953  ...   413.248938   457.142481
# min   -1700.000000 -1200.000000  ...  -550.000000  -275.000000
# 25%    -255.000000  -145.000000  ...   240.000000   325.000000
# 50%    -150.000000   130.000000  ...   435.000000   550.000000
# 75%     127.750000   220.000000  ...   700.000000   881.000000
# max     775.000000  1300.000000  ...  2675.000000  3200.000000
#
# [8 rows x 104 columns]

# %%
df.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'R_odds', 'B_odds', 'R_ev', 'B_ev', 'date',
#        'location', 'country', 'Winner',
#        ...
#        'finish_details', 'finish_round', 'finish_round_time',
#        'total_fight_time_secs', 'r_dec_odds', 'b_dec_odds', 'r_sub_odds',
#        'b_sub_odds', 'r_ko_odds', 'b_ko_odds'],
#       dtype='object', length=119)

# %% [markdown]
# ### Correlation

# %%
plt.figure(figsize=(15, 10))
corr = df.corr()
sns.heatmap(corr, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
corr
# Out:
#               R_odds    B_odds      R_ev  ...  b_sub_odds  r_ko_odds  b_ko_odds
# R_odds      1.000000 -0.971201  0.826073  ...   -0.399905   0.523402  -0.600193
# B_odds     -0.971201  1.000000 -0.882830  ...    0.387747  -0.547977   0.584118
# R_ev        0.826073 -0.882830  1.000000  ...   -0.305392   0.551113  -0.466234
# B_ev       -0.934247  0.891403 -0.641958  ...    0.412879  -0.450153   0.597952
# title_bout -0.143362  0.130749 -0.086623  ...    0.122045  -0.117709   0.022111
# ...              ...       ...       ...  ...         ...        ...        ...
# b_dec_odds -0.666674  0.629175 -0.445603  ...    0.308797  -0.478974   0.190283
# r_sub_odds  0.332317 -0.346209  0.344913  ...   -0.309724  -0.065047  -0.137720
# b_sub_odds -0.399905  0.387747 -0.305392  ...    1.000000  -0.121632   0.022114
# r_ko_odds   0.523402 -0.547977  0.551113  ...   -0.121632   1.000000  -0.216904
# b_ko_odds  -0.600193  0.584118 -0.466234  ...    0.022114  -0.216904   1.000000
#
# ...

# %% [markdown]
# ### Checking for missing data

# %%
df.isnull().sum()
# Out:
# R_fighter        0
# B_fighter        0
# R_odds           0
# B_odds           0
# R_ev             0
#               ...
# b_dec_odds     818
# r_sub_odds    1048
# b_sub_odds    1060
# r_ko_odds     1048
# b_ko_odds     1061
# Length: 119, dtype: int64

# %% [markdown]
# ### Duplicates and Outliers
